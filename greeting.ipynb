# %%
name = input("Enter Your Name: ")
# Out:
# Enter Your Name:  yusuf

# %%
hobby = input("what is your favourite hobby? ")
# Out:
# what is your favourite hobby?  playing football

# %%
print(f"\nHello, {name}! it is great to meet you.")
print(f"i hope you get some time to enjoy {hobby} today!")
# Out:
# Hello, yusuf! it is great to meet you.
# i hope you get some time to enjoy playing football today!
