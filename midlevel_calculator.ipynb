# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
# Out:
# Enter the first number:  25
# Enter the second number:  25

# %%
print("\nChoose an operation:")
print("Type + for Addition")
print("Type - for Substraction")
print("Type * for Multiplication")
print("Type / for Division")
operation = input("Your choice:")
# Out:
# Choose an operation:
# Type + for Addition
# Type - for Substraction
# Type * for Multiplication
# Type / for Division
# Your choice: /

# %%
print("\n---Result---")

if operation == "+":
   result = num1 + num2
   print(f"The answer is: {result}")
elif operation == "-":
   result = num1 - num2
   print(f"The answer is: {result}")
elif operation == "*":
   result = num1 * num2
   print(f"The answer is: {result}")
elif operation == "/":
   result = num1 / num2
   print(f"The answer is: {result}")
else:
   print("Invalid Choice! Please restart and type +,-,* or /.")
# Out:
# ---Result---
# The answer is: 1.0
